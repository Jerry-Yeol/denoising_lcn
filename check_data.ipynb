# %%
import cv2, time
import numpy as np
from utils import *
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
tmp = np.load('/data1/jerry/project/deblurring/data/diff_sig/data_128_medium_3_shuffle.npz')

img = tmp['data']
lab =tmp['label']

print(img.shape)
# Out:
# (3588, 128, 128)

# %%
num = 120

plt.figure(figsize=(16,16))
plt.subplot(141)
plt.imshow(img[num], cmap=plt.cm.bone)
plt.subplot(142)
plt.imshow(lab[num], cmap=plt.cm.bone)
plt.subplot(143)
plt.imshow(img[num], cmap=plt.cm.bone)

plt.show()
